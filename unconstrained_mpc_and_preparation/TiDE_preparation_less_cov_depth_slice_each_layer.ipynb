# %% [markdown]
# # TiDE model for melt pool temperature

# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, TensorDataset
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
if torch.cuda.is_available():
    print("cuda is available")
else:
    print("cuda is NOT available")
torch.cuda.set_device(2)
    
import numpy as np
from tqdm import tqdm
from TiDE import TideModule, quantile_loss
import pickle

import matplotlib.pyplot as plt
import time
import copy

from moving_average import moving_average_1d
# Out:
# cuda is available

# %%
df_all = pd.read_csv('merged_df_2_99_temp_depth.csv')
df_all.shape
# Out:
# (610615, 12)

# %%
nan_rows = df_all[df_all.isna().any(axis=1)]
nan_rows
# Out:
#         time_index  melt_pool_temperature  melt_pool_depth  scanning_speed  \
# 6293    224.912038                    NaN              0.0             7.0
# 6294    224.947778                    NaN              NaN             7.0
# 12588   224.912038                    NaN              0.0             7.0
# 12589   224.947778                    NaN              NaN             7.0
# 18883   224.912038                    NaN              0.0             7.0
# ...            ...                    ...              ...             ...
# 598024  224.947778                    NaN              NaN             7.0
# 604318  224.912038                    NaN              0.0             7.0
# 604319  224.947778                    NaN              NaN             7.0
# 610613  224.912038                    NaN              0.0             7.0
# 610614  224.947778                    NaN              NaN             7.0
#
#                 X          Y    Z  Dist_to_nearest_X  Dist_to_nearest_Y  \
# 6293    17.029661 -18.742469  7.5           2.970339           1.257531
# 6294    17.018514 -18.933201  7.5           2.981486           1.066799
# 12588   17.029661 -18.742469  7.5           2.970339           1.257531
# 12589   17.018514 -18.933201  7.5           2.981486           1.066799
# 18883   17.029661 -18.742469  7.5           2.970339           1.257531
# ...           ...        ...  ...                ...                ...
# 598024  17.018514 -18.933201  7.5           2.981486           1.066799
# 604318  17.029661 -18.742469  7.5           2.970339           1.257531
# 604319  17.018514 -18.933201  7.5           2.981486           1.066799
# 610613  17.029661 -18.742469  7.5           2.970339           1.257531
# 610614  17.018514 -18.933201  7.5           2.981486           1.066799
#
#         Dist_to_nearest_Z  Laser_power  laser_power_number
# 6293                    0   614.885692                   2
# 6294                    0   614.893610                   2
# 12588                   0   633.345179                   3
# 12589                   0   633.341653                   3
# 18883                   0   683.646863                   4
# ...                   ...          ...                 ...
# 598024                  0   642.786355                  97
# 604318                  0   676.289806                  98
# 604319                  0   676.285789                  98
# 610613                  0   655.685110                  99
# 610614                  0   655.659718                  99
#
# [198 rows x 12 columns]

# %%
# df_all = df_all.dropna()
# df_all.shape

# don't drop NAN yet

# %%
# slice data layer-by-layer

stop_flag = 0
safe_data_each_layer = []
start_location = 0
stop_location = 0

for i in range(df_all.shape[0]):
    try:
        layer_height = df_all["Z"][i]
        next_layer_height = df_all["Z"][i+1]
        
        if next_layer_height != layer_height:
            stop_location = i+1
            # append to safe_data_each_layer
            if stop_location - start_location >= 10:
                safe_data_each_layer.append(df_all[start_location:stop_location])
            start_location = i+1
    except:
        stop_location = i
        safe_data_each_layer.append(df_all[start_location:stop_location])

# %%
augmented_data = pd.DataFrame(np.repeat(safe_data_each_layer[1][0:1],50,axis=0))

# %%
# remove NaN from each chunk and remove the numbers after the whole part is completed. append the first W terms in the beginning of each layer 
for i in range(len(safe_data_each_layer)):
    safe_data_each_layer[i] = safe_data_each_layer[i].dropna()
    safe_data_each_layer[i] = safe_data_each_layer[i][0:610]
    augmented_data = pd.concat([safe_data_each_layer[i][0:1]]*50,axis=0)
    safe_data_each_layer[i] = pd.concat([augmented_data, safe_data_each_layer[i]])

# %%
prior_temp = safe_data_each_layer[-1]["melt_pool_temperature"].to_numpy()
prior_depth = safe_data_each_layer[-1]["melt_pool_depth"].to_numpy()

# %%
# moving averge on melt pool temp and depth for each chunk
for i in range(len(safe_data_each_layer)):
    mp_temp_raw = safe_data_each_layer[i]["melt_pool_temperature"].to_numpy()
    mp_temp_mv = moving_average_1d(mp_temp_raw,4)
    mp_temp = copy.deepcopy(mp_temp_raw)
    mp_temp[1:-2] = mp_temp_mv
    safe_data_each_layer[i]["melt_pool_temperature"] = mp_temp
    
    mp_depth_raw = safe_data_each_layer[i]["melt_pool_depth"].to_numpy()
    mp_depth_mv = moving_average_1d(mp_depth_raw,4)
    mp_depth = copy.deepcopy(mp_depth_raw)
    mp_depth[1:-2] = mp_depth_mv
    safe_data_each_layer[i]["melt_pool_depth"] = mp_depth

# %%
post_temp = safe_data_each_layer[-1]["melt_pool_temperature"].to_numpy()
post_depth = safe_data_each_layer[-1]["melt_pool_depth"].to_numpy()

plt.figure()
plt.plot(prior_temp)
plt.plot(post_temp)

plt.figure()
plt.plot(prior_depth)
plt.plot(post_depth)

# %%
# slice data in each chunk and append them into different attribute
total_segments = 0
window = 50
P = 50

for i in range(len(safe_data_each_layer)):
    total_segments = total_segments + safe_data_each_layer[i].shape[0] - window - P

# %%
total_segments
# Out:
# 540484

# %%
# slice each layers and assign them into segments
loc_X = np.zeros((1,total_segments, window + P))
loc_Y = np.zeros((1,total_segments, window + P))
loc_Z = np.zeros((1,total_segments, window + P))
dist_X = np.zeros((1,total_segments, window + P))
dist_Y = np.zeros((1,total_segments, window + P))
scan_spd = np.zeros((1,total_segments, window + P))
laser_power = np.zeros((1,total_segments, window + P))
laser_number = np.zeros((1,total_segments, window + P))
mp_temp = np.zeros((1,total_segments, window + P))
mp_depth = np.zeros((1,total_segments, window + P))



k = 0
for i in range(len(safe_data_each_layer)):
    for j in range(safe_data_each_layer[i].shape[0]-window-P):
        loc_X[0,k,:] = safe_data_each_layer[i]["X"][j:j+window+P]
        loc_Y[0,k,:] = safe_data_each_layer[i]["Y"][j:j+window+P]
        loc_Z[0,k,:] = safe_data_each_layer[i]["Z"][j:j+window+P]
        dist_X[0,k,:] = safe_data_each_layer[i]["Dist_to_nearest_X"][j:j+window+P]
        dist_Y[0,k,:] = safe_data_each_layer[i]["Dist_to_nearest_Y"][j:j+window+P]
        scan_spd[0,k,:] = safe_data_each_layer[i]["scanning_speed"][j:j+window+P]
        laser_power[0,k,:] = safe_data_each_layer[i]["Laser_power"][j:j+window+P]
        laser_number[0,k,:] = safe_data_each_layer[i]["laser_power_number"][j:j+window+P]
        # response
        mp_temp[0,k,:] = safe_data_each_layer[i]["melt_pool_temperature"][j:j+window+P]
        mp_depth[0,k,:] = safe_data_each_layer[i]["melt_pool_depth"][j:j+window+P]
        
        k += 1

# %%
# concat attributes
all_X = np.concatenate([loc_Z, dist_X, dist_Y, laser_power], axis = 0).transpose(1,2,0)
all_Y = np.concatenate([mp_temp, mp_depth], axis = 0).transpose(1,2,0)

# %%
class scalers():
    def __init__(self,x_max, x_min, y_max, y_min) -> None:
        self.x_max = x_max
        self.x_min = x_min
        self.y_max = y_max
        self.y_min = y_min
        
        return None
    
    def scaler_x(self, x_original, dim_id = -1):
        if dim_id == -1:
            x_s = -1 + 2 * ((x_original - self.x_min) / (self.x_max-self.x_min))
            return x_s
        else: 
            x_s = -1 + 2 * (x_original - self.x_min[0,dim_id]) / (self.x_max[0,dim_id] - self.x_min[0,dim_id])
            return x_s
    
    def inv_scaler_x(self, x_s, dim_id = -1):
        
        if dim_id == -1:
            x_original = (x_s + 1)*0.5*(self.x_max-self.x_min) + self.x_min
            return x_original
        else: 
            x_original = (x_s + 1)*0.5*(self.x_max[0,dim_id] - self.x_min[0,dim_id]) + self.x_min[0,dim_id]
            return x_original
        
    def scaler_y(self, y_original):
        return -1 + 2 * ((y_original - self.y_min) / (self.y_max-self.y_min))
    
    def inv_scaler_y(self, y_s):
        return (y_s + 1)*0.5*(self.y_max-self.y_min) + self.y_min

# %%
x_max = np.max(all_X,axis=(0,1)).reshape(1,1,-1)
x_min = np.min(all_X,axis=(0,1)).reshape(1,1,-1)
y_max = np.max(all_Y,axis=(0,1)).reshape(1,1,-1)
y_min = np.min(all_Y,axis=(0,1)).reshape(1,1,-1)

# %%
scaler = scalers(x_max, x_min, y_max, y_min)

x_s = scaler.scaler_x(all_X)
y_s = scaler.scaler_y(all_Y)

# %% [markdown]
# ### Knit data to the required format for training input and output

# %%
cutoff_ratio = 0.9
cutoff_index = int(np.round(cutoff_ratio*x_s.shape[0]))

x_s_train = x_s[:cutoff_index, :, :]
y_s_train = y_s[:cutoff_index, :, :]

x_s_val = x_s[cutoff_index:, :,: ]
y_s_val = y_s[cutoff_index:, :,:]

x_s_train.shape
# Out:
# (486436, 100, 4)

# %%
# ====================== training set =============================================


x_s_train_covariates = x_s_train
y_s_train_past = y_s_train[:,:window,:]
y_s_train_target = y_s_train[:,P:,:]
    

    
# ===================== validation set ============================================


x_s_val_covariates = x_s_val
y_s_val_past = y_s_val[:,:window,:]
y_s_val_target = y_s_val[:,P:,:]

# %%
input_past = torch.tensor(np.concatenate((y_s_train_past,x_s_train_covariates[:,:window,:]),axis=2),dtype=torch.float32).to(device)
input_future = torch.tensor(x_s_train_covariates[:,-P:,:], dtype=torch.float32).to(device)
input_target = torch.tensor(y_s_train_target,dtype=torch.float32).to(device)

val_past = torch.tensor(np.concatenate((y_s_val_past,x_s_val_covariates[:,:window,:]),axis=2),dtype=torch.float32).to(device)
val_future = torch.tensor(x_s_val_covariates[:,-P:,:], dtype=torch.float32).to(device)
val_target = torch.tensor(y_s_val_target,dtype=torch.float32).to(device)

Val_in = [val_past, val_future,None]

print(f"input past shape:{input_past.shape}, input future shape:{input_future.shape}, input target shape:{input_target.shape}")
print(f"val past shape:{val_past.shape}, val future shape:{val_future.shape}, val target shape:{val_target.shape}")
# Out:
# input past shape:torch.Size([486436, 50, 6]), input future shape:torch.Size([486436, 50, 4]), input target shape:torch.Size([486436, 50, 2])
# val past shape:torch.Size([54048, 50, 6]), val future shape:torch.Size([54048, 50, 4]), val target shape:torch.Size([54048, 50, 2])

# %% [markdown]
# ### Setup training model

# %%
output_dim = 2
future_cov_dim = 4

TiDE_MP = TideModule(
        input_dim = output_dim + future_cov_dim,
        output_dim = output_dim,
        future_cov_dim = future_cov_dim,
        static_cov_dim = 0,
        input_chunck_length = window,
        output_chunk_length = P,
        nr_params = 3,
        num_encoder_layers = 1,
        num_decoder_layers = 1,
        decoder_output_dim = 16,
        hidden_size = 128,
        temporal_decoder_hidden = 32,
        temporal_width_past = 4,
        temporal_width_future = 4,
        use_layer_norm = True,
        dropout = 0.2,
    ).to(device)

# # Define optimizer, loss function, and metrics
# optimizer = torch.optim.Adam(TiDE_MP.parameters(),lr=0.001,weight_decay=0.001)
# scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=1, gamma=0.95)
# criterion = quantile_loss
# #criterion = torch.nn.MSELoss()
# num_epoch = 250

# Define optimizer, loss function, and metrics
optimizer = torch.optim.Adam(TiDE_MP.parameters(),lr=0.001,weight_decay=0.001*0.5)
scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=2, gamma=0.95)
criterion = quantile_loss
#criterion = torch.nn.MSELoss()
num_epoch = 400

# %%
# Create DataLoader for training data
train_dataset = TensorDataset(input_past, input_future,input_target)
train_loader = DataLoader(train_dataset, batch_size=128, shuffle=True)

best_model = None
best_validation_loss = float("inf")

save_train_loss = np.zeros(num_epoch)
save_val_loss = np.zeros(num_epoch)

for epoch in range(num_epoch):
    for input_past, input_future, input_target in train_loader:
        x_in = [input_past, input_future, None]

        TiDE_MP.train()
        optimizer.zero_grad()
        output = TiDE_MP(x_in)
        quantiles = [0.1, 0.5, 0.9]
        loss = criterion(output,input_target,quantiles)
        #loss = criterion(output,input_target)
        loss.backward()
        optimizer.step()

    TiDE_MP.eval()
    val_out = TiDE_MP(Val_in)
    val_loss = criterion(val_out,val_target,quantiles)
    #val_loss = criterion(val_out,Val_target)

    if val_loss < best_validation_loss:
        best_val_loss = val_loss
        best_model = TiDE_MP.state_dict()
    
    save_train_loss[epoch] = loss
    save_val_loss[epoch] = val_loss

    scheduler.step()
    
    if epoch % 1 == 0:
        print(f"Epoch = {epoch}, Train loss = {loss:.4f}, Val loss = {val_loss:.4f}")


# Save the model (state_dict) after training
# save DNN parameters
path = ''
sys_params = dict()
sys_params["x_max"] = x_max
sys_params["x_min"] = x_min
sys_params["y_max"] = y_max
sys_params["y_min"] = y_min
sys_params["model"] = TiDE_MP
sys_params["P"] = P
sys_params["window"] = window
pickle.dump(sys_params, open(path + 'TiDE_params_single_track_square_MV_temp_depth_less_cov_sliced_w50_p50.pkl', 'wb'))
# Out:
# Epoch = 0, Train loss = 0.0233, Val loss = 0.0229
# Epoch = 1, Train loss = 0.0200, Val loss = 0.0210
# Epoch = 2, Train loss = 0.0205, Val loss = 0.0189
# Epoch = 3, Train loss = 0.0174, Val loss = 0.0190
# Epoch = 4, Train loss = 0.0198, Val loss = 0.0187
# Epoch = 5, Train loss = 0.0230, Val loss = 0.0311
# Epoch = 6, Train loss = 0.0187, Val loss = 0.0169
# Epoch = 7, Train loss = 0.0168, Val loss = 0.0173
# Epoch = 8, Train loss = 0.0149, Val loss = 0.0168
# Epoch = 9, Train loss = 0.0162, Val loss = 0.0167
# Epoch = 10, Train loss = 0.0176, Val loss = 0.0174
# Epoch = 11, Train loss = 0.0139, Val loss = 0.0180
# Epoch = 12, Train loss = 0.0169, Val loss = 0.0174
# Epoch = 13, Train loss = 0.0122, Val loss = 0.0162
# Epoch = 14, Train loss = 0.0150, Val loss = 0.0158
# Epoch = 15, Train loss = 0.0150, Val loss = 0.0163
# Epoch = 16, Train loss = 0.0213, Val loss = 0.0167
# Epoch = 17, Train loss = 0.0165, Val loss = 0.0161
# Epoch = 18, Train loss = 0.0127, Val loss = 0.0167
# Epoch = 19, Train loss = 0.0195, Val loss = 0.0180
# Epoch = 20, Train loss = 0.0160, Val loss = 0.0169
# Epoch = 21, Train loss = 0.0159, Val loss = 0.0164
# Epoch = 22, Train loss = 0.0184, Val loss = 0.0165
# Epoch = 23, Train loss = 0.0158, Val loss = 0.0158
# Epoch = 24, Train loss = 0.0127, Val loss = 0.0156
# Epoch = 25, Train loss = 0.0152, Val loss = 0.0164
# Epoch = 26, Train loss = 0.0123, Val loss = 0.0155
# Epoch = 27, Train loss = 0.0144, Val loss = 0.0158
# Epoch = 28, Train loss = 0.0186, Val loss = 0.0159
# Epoch = 29, Train loss = 0.0142, Val loss = 0.0153
# Epoch = 30, Train loss = 0.0143, Val loss = 0.0169
# Epoch = 31, Train loss = 0.0155, Val loss = 0.0163
# Epoch = 32, Train loss = 0.0173, Val loss = 0.0171
# Epoch = 33, Train loss = 0.0145, Val loss = 0.0158
# Epoch = 34, Train loss = 0.0157, Val loss = 0.0155
# Epoch = 35, Train loss = 0.0161, Val loss = 0.0151
# Epoch = 36, Train loss = 0.0136, Val loss = 0.0149
# Epoch = 37, Train loss = 0.0169, Val loss = 0.0165
# Epoch = 38, Train loss = 0.0141, Val loss = 0.0157
# Epoch = 39, Train loss = 0.0184, Val loss = 0.0152
# Epoch = 40, Train loss = 0.0149, Val loss = 0.0193
# Epoch = 41, Train loss = 0.0162, Val loss = 0.0154
# Epoch = 42, Train loss = 0.0159, Val loss = 0.0156
# Epoch = 43, Train loss = 0.0174, Val loss = 0.0154
# Epoch = 44, Train loss = 0.0132, Val loss = 0.0149
# Epoch = 45, Train loss = 0.0187, Val loss = 0.0152
# Epoch = 46, Train loss = 0.0171, Val loss = 0.0150
# Epoch = 47, Train loss = 0.0165, Val loss = 0.0149
# Epoch = 48, Train loss = 0.0150, Val loss = 0.0150
# Epoch = 49, Train loss = 0.0227, Val loss = 0.0153
# Epoch = 50, Train loss = 0.0157, Val loss = 0.0153
# Epoch = 51, Train loss = 0.0176, Val loss = 0.0153
# Epoch = 52, Train loss = 0.0155, Val loss = 0.0156
# Epoch = 53, Train loss = 0.0136, Val loss = 0.0157
# Epoch = 54, Train loss = 0.0109, Val loss = 0.0157
# Epoch = 55, Train loss = 0.0136, Val loss = 0.0150
# Epoch = 56, Train loss = 0.0143, Val loss = 0.0149
# Epoch = 57, Train loss = 0.0157, Val loss = 0.0147
# Epoch = 58, Train loss = 0.0169, Val loss = 0.0150
# Epoch = 59, Train loss = 0.0149, Val loss = 0.0151
# Epoch = 60, Train loss = 0.0185, Val loss = 0.0148
# Epoch = 61, Train loss = 0.0176, Val loss = 0.0152
# Epoch = 62, Train loss = 0.0130, Val loss = 0.0160
# Epoch = 63, Train loss = 0.0167, Val loss = 0.0151
# Epoch = 64, Train loss = 0.0159, Val loss = 0.0147
# Epoch = 65, Train loss = 0.0126, Val loss = 0.0147
# Epoch = 66, Train loss = 0.0184, Val loss = 0.0147
# Epoch = 67, Train loss = 0.0174, Val loss = 0.0146
# Epoch = 68, Train loss = 0.0118, Val loss = 0.0147
# Epoch = 69, Train loss = 0.0127, Val loss = 0.0151
# Epoch = 70, Train loss = 0.0165, Val loss = 0.0146
# Epoch = 71, Train loss = 0.0128, Val loss = 0.0148
# Epoch = 72, Train loss = 0.0179, Val loss = 0.0144
# Epoch = 73, Train loss = 0.0136, Val loss = 0.0146
# Epoch = 74, Train loss = 0.0114, Val loss = 0.0148
# Epoch = 75, Train loss = 0.0130, Val loss = 0.0146
# Epoch = 76, Train loss = 0.0142, Val loss = 0.0145
# Epoch = 77, Train loss = 0.0138, Val loss = 0.0146
# Epoch = 78, Train loss = 0.0170, Val loss = 0.0144
# Epoch = 79, Train loss = 0.0160, Val loss = 0.0145
# Epoch = 80, Train loss = 0.0162, Val loss = 0.0144
# Epoch = 81, Train loss = 0.0121, Val loss = 0.0146
# Epoch = 82, Train loss = 0.0131, Val loss = 0.0144
# Epoch = 83, Train loss = 0.0191, Val loss = 0.0144
# Epoch = 84, Train loss = 0.0147, Val loss = 0.0145
# Epoch = 85, Train loss = 0.0153, Val loss = 0.0146
# Epoch = 86, Train loss = 0.0130, Val loss = 0.0144
# Epoch = 87, Train loss = 0.0164, Val loss = 0.0147
# Epoch = 88, Train loss = 0.0153, Val loss = 0.0144
# Epoch = 89, Train loss = 0.0128, Val loss = 0.0143
# Epoch = 90, Train loss = 0.0216, Val loss = 0.0146
# Epoch = 91, Train loss = 0.0127, Val loss = 0.0143
# Epoch = 92, Train loss = 0.0194, Val loss = 0.0148
# Epoch = 93, Train loss = 0.0197, Val loss = 0.0143
# Epoch = 94, Train loss = 0.0136, Val loss = 0.0143
# Epoch = 95, Train loss = 0.0150, Val loss = 0.0142
# Epoch = 96, Train loss = 0.0151, Val loss = 0.0143
# Epoch = 97, Train loss = 0.0167, Val loss = 0.0142
# Epoch = 98, Train loss = 0.0178, Val loss = 0.0143
# Epoch = 99, Train loss = 0.0139, Val loss = 0.0145
# Epoch = 100, Train loss = 0.0156, Val loss = 0.0142
# Epoch = 101, Train loss = 0.0161, Val loss = 0.0144
# Epoch = 102, Train loss = 0.0167, Val loss = 0.0146
# Epoch = 103, Train loss = 0.0125, Val loss = 0.0143
# Epoch = 104, Train loss = 0.0155, Val loss = 0.0143
# Epoch = 105, Train loss = 0.0119, Val loss = 0.0141
# Epoch = 106, Train loss = 0.0168, Val loss = 0.0142
# Epoch = 107, Train loss = 0.0112, Val loss = 0.0142
# Epoch = 108, Train loss = 0.0135, Val loss = 0.0142
# Epoch = 109, Train loss = 0.0181, Val loss = 0.0141
# Epoch = 110, Train loss = 0.0117, Val loss = 0.0140
# Epoch = 111, Train loss = 0.0142, Val loss = 0.0142
# Epoch = 112, Train loss = 0.0142, Val loss = 0.0142
# Epoch = 113, Train loss = 0.0121, Val loss = 0.0141
# Epoch = 114, Train loss = 0.0118, Val loss = 0.0140
# Epoch = 115, Train loss = 0.0207, Val loss = 0.0141
# Epoch = 116, Train loss = 0.0134, Val loss = 0.0139
# Epoch = 117, Train loss = 0.0134, Val loss = 0.0141
# Epoch = 118, Train loss = 0.0143, Val loss = 0.0138
# Epoch = 119, Train loss = 0.0132, Val loss = 0.0138
# Epoch = 120, Train loss = 0.0116, Val loss = 0.0138
# Epoch = 121, Train loss = 0.0136, Val loss = 0.0138
# Epoch = 122, Train loss = 0.0114, Val loss = 0.0136
# Epoch = 123, Train loss = 0.0147, Val loss = 0.0137
# Epoch = 124, Train loss = 0.0142, Val loss = 0.0137
# Epoch = 125, Train loss = 0.0141, Val loss = 0.0136
# Epoch = 126, Train loss = 0.0153, Val loss = 0.0140
# Epoch = 127, Train loss = 0.0112, Val loss = 0.0134
# Epoch = 128, Train loss = 0.0132, Val loss = 0.0135
# Epoch = 129, Train loss = 0.0132, Val loss = 0.0136
# Epoch = 130, Train loss = 0.0162, Val loss = 0.0137
# Epoch = 131, Train loss = 0.0130, Val loss = 0.0133
# Epoch = 132, Train loss = 0.0119, Val loss = 0.0132
# Epoch = 133, Train loss = 0.0148, Val loss = 0.0131
# Epoch = 134, Train loss = 0.0119, Val loss = 0.0133
# Epoch = 135, Train loss = 0.0135, Val loss = 0.0133
# Epoch = 136, Train loss = 0.0128, Val loss = 0.0130
# Epoch = 137, Train loss = 0.0125, Val loss = 0.0129
# Epoch = 138, Train loss = 0.0115, Val loss = 0.0129
# Epoch = 139, Train loss = 0.0123, Val loss = 0.0128
# Epoch = 140, Train loss = 0.0124, Val loss = 0.0128
# Epoch = 141, Train loss = 0.0147, Val loss = 0.0128
# Epoch = 142, Train loss = 0.0124, Val loss = 0.0126
# Epoch = 143, Train loss = 0.0127, Val loss = 0.0128
# Epoch = 144, Train loss = 0.0152, Val loss = 0.0125
# Epoch = 145, Train loss = 0.0127, Val loss = 0.0127
# Epoch = 146, Train loss = 0.0117, Val loss = 0.0124
# Epoch = 147, Train loss = 0.0125, Val loss = 0.0122
# Epoch = 148, Train loss = 0.0156, Val loss = 0.0122
# Epoch = 149, Train loss = 0.0132, Val loss = 0.0125
# Epoch = 150, Train loss = 0.0131, Val loss = 0.0123
# Epoch = 151, Train loss = 0.0124, Val loss = 0.0121
# Epoch = 152, Train loss = 0.0113, Val loss = 0.0121
# Epoch = 153, Train loss = 0.0122, Val loss = 0.0125
# Epoch = 154, Train loss = 0.0133, Val loss = 0.0120
# Epoch = 155, Train loss = 0.0137, Val loss = 0.0121
# Epoch = 156, Train loss = 0.0150, Val loss = 0.0120
# Epoch = 157, Train loss = 0.0123, Val loss = 0.0121
# Epoch = 158, Train loss = 0.0113, Val loss = 0.0119
# Epoch = 159, Train loss = 0.0117, Val loss = 0.0121
# Epoch = 160, Train loss = 0.0121, Val loss = 0.0122
# Epoch = 161, Train loss = 0.0105, Val loss = 0.0121
# Epoch = 162, Train loss = 0.0151, Val loss = 0.0120
# Epoch = 163, Train loss = 0.0135, Val loss = 0.0119
# Epoch = 164, Train loss = 0.0101, Val loss = 0.0119
# Epoch = 165, Train loss = 0.0112, Val loss = 0.0118
# Epoch = 166, Train loss = 0.0111, Val loss = 0.0119
# Epoch = 167, Train loss = 0.0115, Val loss = 0.0120
# Epoch = 168, Train loss = 0.0164, Val loss = 0.0119
# Epoch = 169, Train loss = 0.0111, Val loss = 0.0117
# Epoch = 170, Train loss = 0.0115, Val loss = 0.0118
# Epoch = 171, Train loss = 0.0121, Val loss = 0.0121
# Epoch = 172, Train loss = 0.0115, Val loss = 0.0119
# Epoch = 173, Train loss = 0.0107, Val loss = 0.0117
# Epoch = 174, Train loss = 0.0135, Val loss = 0.0117
# Epoch = 175, Train loss = 0.0142, Val loss = 0.0116
# Epoch = 176, Train loss = 0.0123, Val loss = 0.0118
# Epoch = 177, Train loss = 0.0120, Val loss = 0.0117
# Epoch = 178, Train loss = 0.0116, Val loss = 0.0117
# Epoch = 179, Train loss = 0.0152, Val loss = 0.0116
# Epoch = 180, Train loss = 0.0131, Val loss = 0.0120
# Epoch = 181, Train loss = 0.0107, Val loss = 0.0116
# Epoch = 182, Train loss = 0.0110, Val loss = 0.0115
# Epoch = 183, Train loss = 0.0139, Val loss = 0.0115
# Epoch = 184, Train loss = 0.0125, Val loss = 0.0116
# Epoch = 185, Train loss = 0.0108, Val loss = 0.0114
# Epoch = 186, Train loss = 0.0128, Val loss = 0.0115
# Epoch = 187, Train loss = 0.0117, Val loss = 0.0116
# Epoch = 188, Train loss = 0.0138, Val loss = 0.0115
# Epoch = 189, Train loss = 0.0100, Val loss = 0.0115
# Epoch = 190, Train loss = 0.0106, Val loss = 0.0114
# Epoch = 191, Train loss = 0.0120, Val loss = 0.0115
# Epoch = 192, Train loss = 0.0106, Val loss = 0.0114
# Epoch = 193, Train loss = 0.0119, Val loss = 0.0114
# Epoch = 194, Train loss = 0.0158, Val loss = 0.0114
# Epoch = 195, Train loss = 0.0106, Val loss = 0.0113
# Epoch = 196, Train loss = 0.0118, Val loss = 0.0113
# Epoch = 197, Train loss = 0.0116, Val loss = 0.0113
# Epoch = 198, Train loss = 0.0111, Val loss = 0.0114
# Epoch = 199, Train loss = 0.0148, Val loss = 0.0113
# Epoch = 200, Train loss = 0.0105, Val loss = 0.0113
# Epoch = 201, Train loss = 0.0119, Val loss = 0.0113
# Epoch = 202, Train loss = 0.0115, Val loss = 0.0114
# Epoch = 203, Train loss = 0.0128, Val loss = 0.0113
# Epoch = 204, Train loss = 0.0131, Val loss = 0.0113
# Epoch = 205, Train loss = 0.0120, Val loss = 0.0113
# Epoch = 206, Train loss = 0.0114, Val loss = 0.0113
# Epoch = 207, Train loss = 0.0099, Val loss = 0.0112
# Epoch = 208, Train loss = 0.0137, Val loss = 0.0113
# Epoch = 209, Train loss = 0.0128, Val loss = 0.0113
# Epoch = 210, Train loss = 0.0105, Val loss = 0.0112
# Epoch = 211, Train loss = 0.0114, Val loss = 0.0113
# Epoch = 212, Train loss = 0.0121, Val loss = 0.0112
# Epoch = 213, Train loss = 0.0135, Val loss = 0.0112
# Epoch = 214, Train loss = 0.0107, Val loss = 0.0114
# Epoch = 215, Train loss = 0.0097, Val loss = 0.0113
# Epoch = 216, Train loss = 0.0116, Val loss = 0.0112
# Epoch = 217, Train loss = 0.0110, Val loss = 0.0112
# Epoch = 218, Train loss = 0.0108, Val loss = 0.0113
# Epoch = 219, Train loss = 0.0137, Val loss = 0.0112
# Epoch = 220, Train loss = 0.0110, Val loss = 0.0112
# Epoch = 221, Train loss = 0.0122, Val loss = 0.0112
# Epoch = 222, Train loss = 0.0120, Val loss = 0.0112
# Epoch = 223, Train loss = 0.0132, Val loss = 0.0112
# Epoch = 224, Train loss = 0.0127, Val loss = 0.0112
# Epoch = 225, Train loss = 0.0115, Val loss = 0.0111
# Epoch = 226, Train loss = 0.0110, Val loss = 0.0114
# Epoch = 227, Train loss = 0.0124, Val loss = 0.0112
# Epoch = 228, Train loss = 0.0107, Val loss = 0.0111
# Epoch = 229, Train loss = 0.0116, Val loss = 0.0113
# Epoch = 230, Train loss = 0.0163, Val loss = 0.0112
# Epoch = 231, Train loss = 0.0103, Val loss = 0.0111
# Epoch = 232, Train loss = 0.0123, Val loss = 0.0111
# Epoch = 233, Train loss = 0.0109, Val loss = 0.0111
# Epoch = 234, Train loss = 0.0115, Val loss = 0.0111
# Epoch = 235, Train loss = 0.0105, Val loss = 0.0112
# Epoch = 236, Train loss = 0.0122, Val loss = 0.0112
# Epoch = 237, Train loss = 0.0097, Val loss = 0.0111
# Epoch = 238, Train loss = 0.0108, Val loss = 0.0111
# Epoch = 239, Train loss = 0.0114, Val loss = 0.0111
# Epoch = 240, Train loss = 0.0146, Val loss = 0.0111
# Epoch = 241, Train loss = 0.0124, Val loss = 0.0111
# Epoch = 242, Train loss = 0.0108, Val loss = 0.0112
# Epoch = 243, Train loss = 0.0112, Val loss = 0.0111
# Epoch = 244, Train loss = 0.0112, Val loss = 0.0110
# Epoch = 245, Train loss = 0.0102, Val loss = 0.0111
# Epoch = 246, Train loss = 0.0119, Val loss = 0.0111
# Epoch = 247, Train loss = 0.0104, Val loss = 0.0111
# Epoch = 248, Train loss = 0.0110, Val loss = 0.0110
# Epoch = 249, Train loss = 0.0095, Val loss = 0.0110
# Epoch = 250, Train loss = 0.0119, Val loss = 0.0110
# Epoch = 251, Train loss = 0.0100, Val loss = 0.0111
# Epoch = 252, Train loss = 0.0113, Val loss = 0.0110
# Epoch = 253, Train loss = 0.0109, Val loss = 0.0110
# Epoch = 254, Train loss = 0.0113, Val loss = 0.0110
# Epoch = 255, Train loss = 0.0124, Val loss = 0.0110
# Epoch = 256, Train loss = 0.0144, Val loss = 0.0111
# Epoch = 257, Train loss = 0.0105, Val loss = 0.0110
# Epoch = 258, Train loss = 0.0104, Val loss = 0.0111
# Epoch = 259, Train loss = 0.0114, Val loss = 0.0110
# Epoch = 260, Train loss = 0.0106, Val loss = 0.0110
# Epoch = 261, Train loss = 0.0099, Val loss = 0.0110
# Epoch = 262, Train loss = 0.0119, Val loss = 0.0110
# Epoch = 263, Train loss = 0.0091, Val loss = 0.0110
# Epoch = 264, Train loss = 0.0120, Val loss = 0.0110
# Epoch = 265, Train loss = 0.0103, Val loss = 0.0110
# Epoch = 266, Train loss = 0.0102, Val loss = 0.0110
# Epoch = 267, Train loss = 0.0117, Val loss = 0.0110
# Epoch = 268, Train loss = 0.0109, Val loss = 0.0110
# Epoch = 269, Train loss = 0.0109, Val loss = 0.0110
# Epoch = 270, Train loss = 0.0120, Val loss = 0.0110
# Epoch = 271, Train loss = 0.0133, Val loss = 0.0110
# Epoch = 272, Train loss = 0.0155, Val loss = 0.0110
# Epoch = 273, Train loss = 0.0109, Val loss = 0.0111
# Epoch = 274, Train loss = 0.0117, Val loss = 0.0110
# Epoch = 275, Train loss = 0.0120, Val loss = 0.0110
# Epoch = 276, Train loss = 0.0101, Val loss = 0.0110
# Epoch = 277, Train loss = 0.0106, Val loss = 0.0110
# Epoch = 278, Train loss = 0.0107, Val loss = 0.0110
# Epoch = 279, Train loss = 0.0109, Val loss = 0.0110
# Epoch = 280, Train loss = 0.0104, Val loss = 0.0110
# Epoch = 281, Train loss = 0.0109, Val loss = 0.0110
# Epoch = 282, Train loss = 0.0121, Val loss = 0.0110
# Epoch = 283, Train loss = 0.0111, Val loss = 0.0110
# Epoch = 284, Train loss = 0.0115, Val loss = 0.0110
# Epoch = 285, Train loss = 0.0135, Val loss = 0.0110
# Epoch = 286, Train loss = 0.0116, Val loss = 0.0110
# Epoch = 287, Train loss = 0.0111, Val loss = 0.0110
# Epoch = 288, Train loss = 0.0109, Val loss = 0.0110
# Epoch = 289, Train loss = 0.0112, Val loss = 0.0110
# Epoch = 290, Train loss = 0.0105, Val loss = 0.0110
# Epoch = 291, Train loss = 0.0104, Val loss = 0.0110
# Epoch = 292, Train loss = 0.0094, Val loss = 0.0110
# Epoch = 293, Train loss = 0.0126, Val loss = 0.0110
# Epoch = 294, Train loss = 0.0095, Val loss = 0.0110
# Epoch = 295, Train loss = 0.0120, Val loss = 0.0109
# Epoch = 296, Train loss = 0.0108, Val loss = 0.0110
# Epoch = 297, Train loss = 0.0115, Val loss = 0.0109
# Epoch = 298, Train loss = 0.0100, Val loss = 0.0109
# Epoch = 299, Train loss = 0.0106, Val loss = 0.0109
# Epoch = 300, Train loss = 0.0110, Val loss = 0.0110
# Epoch = 301, Train loss = 0.0112, Val loss = 0.0110
# Epoch = 302, Train loss = 0.0113, Val loss = 0.0110
# Epoch = 303, Train loss = 0.0113, Val loss = 0.0110
# Epoch = 304, Train loss = 0.0132, Val loss = 0.0109
# Epoch = 305, Train loss = 0.0102, Val loss = 0.0109
# Epoch = 306, Train loss = 0.0126, Val loss = 0.0109
# Epoch = 307, Train loss = 0.0117, Val loss = 0.0109
# Epoch = 308, Train loss = 0.0123, Val loss = 0.0109
# Epoch = 309, Train loss = 0.0117, Val loss = 0.0109
# Epoch = 310, Train loss = 0.0113, Val loss = 0.0110
# Epoch = 311, Train loss = 0.0139, Val loss = 0.0109
# Epoch = 312, Train loss = 0.0118, Val loss = 0.0110
# Epoch = 313, Train loss = 0.0091, Val loss = 0.0110
# Epoch = 314, Train loss = 0.0106, Val loss = 0.0109
# Epoch = 315, Train loss = 0.0139, Val loss = 0.0109
# Epoch = 316, Train loss = 0.0107, Val loss = 0.0110
# Epoch = 317, Train loss = 0.0127, Val loss = 0.0109
# Epoch = 318, Train loss = 0.0101, Val loss = 0.0109
# Epoch = 319, Train loss = 0.0119, Val loss = 0.0109
# Epoch = 320, Train loss = 0.0110, Val loss = 0.0109
# Epoch = 321, Train loss = 0.0122, Val loss = 0.0109
# Epoch = 322, Train loss = 0.0105, Val loss = 0.0109
# Epoch = 323, Train loss = 0.0108, Val loss = 0.0109
# Epoch = 324, Train loss = 0.0103, Val loss = 0.0109
# Epoch = 325, Train loss = 0.0102, Val loss = 0.0109
# Epoch = 326, Train loss = 0.0117, Val loss = 0.0109
# Epoch = 327, Train loss = 0.0094, Val loss = 0.0109
# Epoch = 328, Train loss = 0.0118, Val loss = 0.0109
# Epoch = 329, Train loss = 0.0107, Val loss = 0.0109
# Epoch = 330, Train loss = 0.0116, Val loss = 0.0109
# Epoch = 331, Train loss = 0.0108, Val loss = 0.0109
# Epoch = 332, Train loss = 0.0106, Val loss = 0.0109
# Epoch = 333, Train loss = 0.0113, Val loss = 0.0109
# Epoch = 334, Train loss = 0.0145, Val loss = 0.0109
# Epoch = 335, Train loss = 0.0103, Val loss = 0.0109
# Epoch = 336, Train loss = 0.0102, Val loss = 0.0109
# Epoch = 337, Train loss = 0.0102, Val loss = 0.0109
# Epoch = 338, Train loss = 0.0111, Val loss = 0.0109
# Epoch = 339, Train loss = 0.0092, Val loss = 0.0109
# Epoch = 340, Train loss = 0.0099, Val loss = 0.0109
# Epoch = 341, Train loss = 0.0134, Val loss = 0.0109
# Epoch = 342, Train loss = 0.0125, Val loss = 0.0109
# Epoch = 343, Train loss = 0.0134, Val loss = 0.0109
# Epoch = 344, Train loss = 0.0120, Val loss = 0.0109
# Epoch = 345, Train loss = 0.0151, Val loss = 0.0109
# Epoch = 346, Train loss = 0.0120, Val loss = 0.0109
# Epoch = 347, Train loss = 0.0126, Val loss = 0.0109
# Epoch = 348, Train loss = 0.0099, Val loss = 0.0109
# Epoch = 349, Train loss = 0.0095, Val loss = 0.0109
# Epoch = 350, Train loss = 0.0095, Val loss = 0.0109
# Epoch = 351, Train loss = 0.0133, Val loss = 0.0109
# Epoch = 352, Train loss = 0.0108, Val loss = 0.0109
# Epoch = 353, Train loss = 0.0099, Val loss = 0.0109
# Epoch = 354, Train loss = 0.0144, Val loss = 0.0109
# Epoch = 355, Train loss = 0.0106, Val loss = 0.0109
# Epoch = 356, Train loss = 0.0136, Val loss = 0.0109
# Epoch = 357, Train loss = 0.0113, Val loss = 0.0109
# Epoch = 358, Train loss = 0.0119, Val loss = 0.0109
# Epoch = 359, Train loss = 0.0115, Val loss = 0.0109
# Epoch = 360, Train loss = 0.0103, Val loss = 0.0109
# Epoch = 361, Train loss = 0.0125, Val loss = 0.0109
# Epoch = 362, Train loss = 0.0130, Val loss = 0.0109
# Epoch = 363, Train loss = 0.0106, Val loss = 0.0109
# Epoch = 364, Train loss = 0.0158, Val loss = 0.0109
# Epoch = 365, Train loss = 0.0114, Val loss = 0.0109
# Epoch = 366, Train loss = 0.0141, Val loss = 0.0109
# Epoch = 367, Train loss = 0.0123, Val loss = 0.0109
# Epoch = 368, Train loss = 0.0104, Val loss = 0.0109
# Epoch = 369, Train loss = 0.0117, Val loss = 0.0109
# Epoch = 370, Train loss = 0.0103, Val loss = 0.0109
# Epoch = 371, Train loss = 0.0107, Val loss = 0.0109
# Epoch = 372, Train loss = 0.0103, Val loss = 0.0109
# Epoch = 373, Train loss = 0.0106, Val loss = 0.0109
# Epoch = 374, Train loss = 0.0115, Val loss = 0.0109
# Epoch = 375, Train loss = 0.0109, Val loss = 0.0109
# Epoch = 376, Train loss = 0.0133, Val loss = 0.0109
# Epoch = 377, Train loss = 0.0132, Val loss = 0.0109
# Epoch = 378, Train loss = 0.0117, Val loss = 0.0109
# Epoch = 379, Train loss = 0.0121, Val loss = 0.0109
# Epoch = 380, Train loss = 0.0118, Val loss = 0.0109
# Epoch = 381, Train loss = 0.0113, Val loss = 0.0109
# Epoch = 382, Train loss = 0.0110, Val loss = 0.0109
# Epoch = 383, Train loss = 0.0105, Val loss = 0.0109
# Epoch = 384, Train loss = 0.0139, Val loss = 0.0109
# Epoch = 385, Train loss = 0.0093, Val loss = 0.0109
# Epoch = 386, Train loss = 0.0123, Val loss = 0.0109
# Epoch = 387, Train loss = 0.0106, Val loss = 0.0109
# Epoch = 388, Train loss = 0.0106, Val loss = 0.0109
# Epoch = 389, Train loss = 0.0115, Val loss = 0.0109
# Epoch = 390, Train loss = 0.0097, Val loss = 0.0109
# Epoch = 391, Train loss = 0.0107, Val loss = 0.0109
# Epoch = 392, Train loss = 0.0113, Val loss = 0.0109
# Epoch = 393, Train loss = 0.0120, Val loss = 0.0109
# Epoch = 394, Train loss = 0.0110, Val loss = 0.0109
# Epoch = 395, Train loss = 0.0105, Val loss = 0.0109
# Epoch = 396, Train loss = 0.0102, Val loss = 0.0109
# Epoch = 397, Train loss = 0.0112, Val loss = 0.0109
# Epoch = 398, Train loss = 0.0099, Val loss = 0.0109
# Epoch = 399, Train loss = 0.0089, Val loss = 0.0109

# %%
# Save the model (state_dict) after training
# save DNN parameters
path = ''
sys_params = dict()
sys_params["x_max"] = x_max
sys_params["x_min"] = x_min
sys_params["y_max"] = y_max
sys_params["y_min"] = y_min
sys_params["model"] = TiDE_MP
sys_params["P"] = P
sys_params["window"] = window
pickle.dump(sys_params, open(path + 'TiDE_params_single_track_square_MV_temp_depth_less_cov_sliced_w50_p50.pkl', 'wb'))

# %%
# with open('TiDE_params_single_track_square_MV_temp_depth_less_cov_0915_w50_p50.pkl', 'rb') as file:
#     # 2. Load the data from the pickle file
#     nominal_params = pickle.load(file)
# # Load nominal TiDE model
# TiDE_MP = nominal_params['model'].to(device)

# %%
# Plot loss
loss = save_train_loss
val_loss = save_val_loss
epochs=range(1,len(loss)+1)
plt.figure()
plt.semilogy(epochs, loss,'b', label='Training loss')
plt.semilogy(epochs, val_loss,'r', label='Validation loss')
plt.title('Training and validation losses')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.xscale('log')
#plt.yscale('log')
plt.legend()
#plt.savefig('lossLSTM32.png')
plt.show()

# %%
data = {
    'train_loss': loss,
    'val_loss': val_loss
}

# Create a DataFrame
df = pd.DataFrame(data)

# Save the DataFrame to a CSV file
df.to_csv('loss_save.csv', index=False)

# %%
item = 800 # Select the index for visualizing the results using validation data
#item = 7060
item = 6725



x_plot_past = val_past[item,:,:].unsqueeze(0)
x_plot_future = val_future[item,:,:].unsqueeze(0)
x_plot_val = [x_plot_past, x_plot_future, None]
y_plot_val = val_target[item,:,:].unsqueeze(0)

TiDE_MP.eval()

time1 = time.time()
y_hat = TiDE_MP(x_plot_val)
time2 = time.time()
print(f"forward time = {time2-time1}")

# plot x1
plt.figure()
y_true_original = scaler.inv_scaler_y(y_plot_val.to("cpu")[:,:,:].squeeze().numpy())
plt.plot(y_true_original[0][:,0],label="Original Data")

y_hat_original = scaler.inv_scaler_y(y_hat[:,:,:,1].squeeze().detach().to("cpu").numpy())
plt.plot(y_hat_original[0][:,0],label="Median")

y_hat_ub_original = scaler.inv_scaler_y(y_hat[:,:,:,0].squeeze().detach().to("cpu").numpy())
plt.plot(y_hat_ub_original[0][:,0],label="Lower quantile")

y_hat_lb_original = scaler.inv_scaler_y(y_hat[:,:,:,2].squeeze().detach().to("cpu").numpy())
plt.plot(y_hat_lb_original[0][:,0],label="Upper quantile")

plt.title('Predicted quantile for x1')
plt.xlabel('time step')

# #plt.ylim([3000,4000])
# # plt.xlim([0,19])

plt.fill_between(range(P),
                 y1=y_hat_ub_original[0][:,0],
                 y2=y_hat_lb_original[0][:,0],
                 alpha=0.2, color='gray')
plt.legend()

plt.figure()
plt.plot(y_true_original[0][:,1],label="Original Data")
plt.plot(y_hat_original[0][:,1],label="Median")

y_hat_ub_original = scaler.inv_scaler_y(y_hat[:,:,:,0].squeeze().detach().to("cpu").numpy())
plt.plot(y_hat_ub_original[0][:,1],label="Lower quantile")

y_hat_lb_original = scaler.inv_scaler_y(y_hat[:,:,:,2].squeeze().detach().to("cpu").numpy())
plt.plot(y_hat_lb_original[0][:,1],label="Upper quantile")
plt.fill_between(range(P),
                 y1=y_hat_ub_original[0][:,1],
                 y2=y_hat_lb_original[0][:,1],
                 alpha=0.2, color='gray')
plt.legend()
# Out:
# forward time = 0.0012006759643554688

# %%
y_true_original.shape
# Out:
# (1, 50, 2)

# %%
item = 800
item = 9200
# item = 9340 # corner
# item = 56223
item = 16425 # corner
# item = 11575 # corner
# item = 5572 # new layer

x_plot_past = val_past[item,:,:].unsqueeze(0)
x_plot_future = val_future[item,:,:].unsqueeze(0)
x_plot_val = [x_plot_past, x_plot_future, None]
y_plot_val = val_target[item,:,:].unsqueeze(0)

TiDE_MP.eval()

time1 = time.time()
y_hat = TiDE_MP(x_plot_val)
time2 = time.time()
print(f"forward time = {time2-time1}")

# plot x1
y_plot_past = scaler.inv_scaler_y(x_plot_past[:,:,0:2].to("cpu"))

plt.figure(figsize=[12,6])
y_hat_upper = scaler.inv_scaler_y(y_hat[:,:,0:2,2].squeeze().detach().to("cpu").numpy())
y_hat_lower = scaler.inv_scaler_y(y_hat[:,:,0:2,0].squeeze().detach().to("cpu").numpy())
y_true_original = scaler.inv_scaler_y(y_plot_val.to("cpu")[:,:,0:2].squeeze().numpy())
plt.plot(np.linspace(P+1,P*2,P),y_true_original[0][:,0],label="Original Data")
plt.fill_between(np.linspace(P+1,P*2,P),y_hat_lower[0][:,0],y_hat_upper[0][:,0],color = 'gray', alpha = 0.5)

y_hat_original = scaler.inv_scaler_y(y_hat[:,:,0:2,1].squeeze().detach().to("cpu").numpy())
plt.plot(np.linspace(P+1,P*2,P),y_hat_original[0][:,0],label="Median")
plt.plot(np.linspace(1,P,P),y_plot_past[:,:,0].squeeze(0), label="Past")


plt.title('Predicted quantile for x1')
plt.xlabel('time step')


plt.xlim([1,100])

plt.legend()

# =======================================================================

plt.figure(figsize=[12,6])
y_hat_upper = scaler.inv_scaler_y(y_hat[:,:,0:2,2].squeeze().detach().to("cpu").numpy())
y_hat_lower = scaler.inv_scaler_y(y_hat[:,:,0:2,0].squeeze().detach().to("cpu").numpy())
plt.plot(np.linspace(P+1,P*2,P),y_true_original[0][:,1],label="Original Data")
plt.plot(np.linspace(P+1,P*2,P),y_hat_original[0][:,1],label="Median")
plt.plot(np.linspace(1,P,P),y_plot_past[:,:,1].squeeze(0), label="Past")
plt.fill_between(np.linspace(P+1,P*2,P),y_hat_lower[0][:,1],y_hat_upper[0][:,1],color = 'gray', alpha = 0.5)

plt.title('Predicted quantile for x1')
plt.xlabel('time step')


plt.xlim([1,100])

plt.legend()
# Out:
# forward time = 0.02337193489074707

# %%
aa = y_true_original[:,0]
#aa = y_hat_original[:,0]
#aa = y_plot_past[:,:,0]
aa
# Out:
# array([[ 2.36117098e+03, -4.89795934e-01]])

# %%
from matplotlib.animation import FuncAnimation
from IPython.display import HTML

iters = 600

# Set up the figure
fig, ax = plt.subplots(figsize=(9, 4), dpi=100)
ax.set_xlabel("Time",fontsize=14)
ax.set_ylabel("x1",fontsize=14)
line_past, = ax.plot([], [], "-", linewidth=1.5, color="red", label="Past MP Temp")
line_true, = ax.plot([], [], "-", linewidth=1.5, color="green", label="True MP Temp")
line_pred, = ax.plot([], [], "-", linewidth=1.5, color="blue", label="Pred MP Temp")

plt.xlim(1,100)
plt.ylim(1900,4400)

ax.legend(loc='lower right')

# Function to update the plot in each iteration
def update(iter):
    x_plot_past = val_past[iter,:,:].unsqueeze(0)
    x_plot_future = val_future[iter,:,:].unsqueeze(0)
    x_plot_val = [x_plot_past, x_plot_future, None]
    y_plot_val = val_target[iter,:,:].unsqueeze(0)

    TiDE_MP.eval()

    y_hat = TiDE_MP(x_plot_val)


    # plot x1
    y_plot_past = scaler.inv_scaler_y(x_plot_past[:,:,0].to("cpu"))
    y_true_original = scaler.inv_scaler_y(y_plot_val.to("cpu")[:,:,0].squeeze().numpy())
    y_hat_original = scaler.inv_scaler_y(y_hat[:,:,0,1].squeeze().detach().to("cpu").numpy())
    
    line_past.set_data(np.linspace(1,P,P), y_plot_past.T)
    line_true.set_data(np.linspace(P+1,P*2,P), y_true_original.T)
    line_pred.set_data(np.linspace(P+1,P*2,P), y_hat_original.T)
    # ax.collections[-1].remove()
    plt.title(f"step {iter}")
    return line_past, line_pred, line_true

animation = FuncAnimation(fig, update, frames=iters,  blit=True)

# # Show the animation
HTML(animation.to_jshtml())
plt.rcParams["animation.html"] = "jshtml"
animation.save('validation.gif', writer='imagemagick', fps=10)
animation
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 43
#      40     plt.title(f"step {iter}")
#      41     return line_past, line_pred, line_true
# ---> 43 animation = FuncAnimation(fig, update, frames=iters,  blit=True)
#      45 # # Show the animation
#      46 HTML(animation.to_jshtml())
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:1695, in FuncAnimation.__init__(self, fig, func, frames, init_func, fargs, save_count, cache_frame_data, **kwargs)
#    1692 # Needs to be initialized so the draw functions work without checking
#    1693 self._save_seq = []
# -> 1695 super().__init__(fig, **kwargs)
#    1697 # Need to reset the saved seq, since right now it will contain data
#    1698 # for a single frame from init, which is not what we want.
#    1699 self._save_seq = []
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:1417, in TimedAnimation.__init__(self, fig, interval, repeat_delay, repeat, event_source, *args, **kwargs)
#    1415 if event_source is None:
#    1416     event_source = fig.canvas.new_timer(interval=self._interval)
# -> 1417 super().__init__(fig, event_source=event_source, *args, **kwargs)
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:888, in Animation.__init__(self, fig, event_source, blit)
#     885 self._close_id = self._fig.canvas.mpl_connect('close_event',
#     886                                               self._stop)
#     887 if self._blit:
# --> 888     self._setup_blit()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:1211, in Animation._setup_blit(self)
#    1209 self._drawn_artists = []
#    1210 # _post_draw needs to be called first to initialize the renderer
# -> 1211 self._post_draw(None, self._blit)
#    1212 # Then we need to clear the Frame for the initial draw
#    1213 # This is typically handled in _on_resize because QT and Tk
#    1214 # emit a resize event on launch, but the macosx backend does not,
#    1215 # thus we force it here for everyone for consistency
#    1216 self._init_draw()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:1166, in Animation._post_draw(self, framedata, blit)
#    1164     self._blit_draw(self._drawn_artists)
#    1165 else:
# -> 1166     self._fig.canvas.draw_idle()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/backend_bases.py:1893, in FigureCanvasBase.draw_idle(self, *args, **kwargs)
#    1891 if not self._is_idle_drawing:
#    1892     with self._idle_draw_cntx():
# -> 1893         self.draw(*args, **kwargs)
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:388, in FigureCanvasAgg.draw(self)
#     385 # Acquire a lock on the shared font cache.
#     386 with (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     387       else nullcontext()):
# --> 388     self.figure.draw(self.renderer)
#     389     # A GUI class may be need to update a window using this draw, so
#     390     # don't forget to call the superclass.
#     391     super().draw()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/artist.py:95, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      93 @wraps(draw)
#      94 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 95     result = draw(artist, renderer, *args, **kwargs)
#      96     if renderer._rasterizing:
#      97         renderer.stop_rasterizing()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/artist.py:72, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      69     if artist.get_agg_filter() is not None:
#      70         renderer.start_filter()
# ---> 72     return draw(artist, renderer)
#      73 finally:
#      74     if artist.get_agg_filter() is not None:
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/figure.py:3164, in Figure.draw(self, renderer)
#    3161 finally:
#    3162     self.stale = False
# -> 3164 DrawEvent("draw_event", self.canvas, renderer)._process()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/backend_bases.py:1271, in Event._process(self)
#    1269 def _process(self):
#    1270     """Process this event on ``self.canvas``, then unset ``guiEvent``."""
# -> 1271     self.canvas.callbacks.process(self.name, self)
#    1272     self._guiEvent_deleted = True
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/cbook.py:303, in CallbackRegistry.process(self, s, *args, **kwargs)
#     301 except Exception as exc:
#     302     if self.exception_handler is not None:
# --> 303         self.exception_handler(exc)
#     304     else:
#     305         raise
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/cbook.py:87, in _exception_printer(exc)
#      85 def _exception_printer(exc):
#      86     if _get_running_interactive_framework() in ["headless", None]:
# ---> 87         raise exc
#      88     else:
#      89         traceback.print_exc()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/cbook.py:298, in CallbackRegistry.process(self, s, *args, **kwargs)
#     296 if func is not None:
#     297     try:
# --> 298         func(*args, **kwargs)
#     299     # this does not capture KeyboardInterrupt, SystemExit,
#     300     # and GeneratorExit
#     301     except Exception as exc:
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:912, in Animation._start(self, *args)
#     909 self._fig.canvas.mpl_disconnect(self._first_draw_id)
#     911 # Now do any initial draw
# --> 912 self._init_draw()
#     914 # Add our callback for stepping the animation and
#     915 # actually start the event_source.
#     916 self.event_source.add_callback(self._step)
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:1749, in FuncAnimation._init_draw(self)
#    1741         warnings.warn(
#    1742             "Can not start iterating the frames for the initial draw. "
#    1743             "This can be caused by passing in a 0 length sequence "
#    (...)
#    1746             "it may be exhausted due to a previous display or save."
#    1747         )
#    1748         return
# -> 1749     self._draw_frame(frame_data)
#    1750 else:
#    1751     self._drawn_artists = self._init_func()
#
# File ~/miniconda3/envs/GAMMA_TiDE/lib/python3.10/site-packages/matplotlib/animation.py:1768, in FuncAnimation._draw_frame(self, framedata)
#    1764     self._save_seq = self._save_seq[-self._save_count:]
#    1766 # Call the func with framedata and args. If blitting is desired,
#    1767 # func needs to return a sequence of any artists that were modified.
# -> 1768 self._drawn_artists = self._func(framedata, *self._args)
#    1770 if self._blit:
#    1772     err = RuntimeError('The animation function must return a sequence '
#    1773                        'of Artist objects.')
#
# Cell In[48], line 32, in update(iter)
#      28 y_hat = TiDE_MP(x_plot_val)
#      31 # plot x1
# ---> 32 y_plot_past = scaler.inv_scaler_y(x_plot_past[:,:,0].to("cpu"))
#      33 y_true_original = scaler.inv_scaler_y(y_plot_val.to("cpu")[:,:,0].squeeze().numpy())
#      34 y_hat_original = scaler.inv_scaler_y(y_hat[:,:,0,1].squeeze().detach().to("cpu").numpy())
#
# Cell In[15], line 31, in scalers.inv_scaler_y(self, y_s)
#      30 def inv_scaler_y(self, y_s):
# ---> 31     return (y_s + 1)*0.5*(self.y_max-self.y_min) + self.y_min
#
# ValueError: operands could not be broadcast together with shapes (1,50) (1,1,2)

# %% [markdown]
# ### Evaluation

# %%
def sMAPE(y_true,y_hat):
    MAPE_ind = 100* np.mean(np.abs((y_true - y_hat) / (np.abs(y_true)+np.abs(y_hat))))
    return MAPE_ind

def SSE_compute(y_true, y_hat):
    return np.sum((y_true - y_hat)**2)

# Main code for eval
MAPE_x1 = np.empty((val_past.shape[0]))
MAPE_x2 = np.empty((val_past.shape[0]))

SSE_x1 = 0
SSE_x2 = 0


for item in tqdm(range(val_past.shape[0])):
    x_past = val_past[item,:,:].unsqueeze(0)
    x_future = val_future[item,:,:].unsqueeze(0)
    x_val = [x_past, x_future, None]
    y_val = val_target[item,:,:].unsqueeze(0)
    y_hat = TiDE_MP(x_val)
    # sMAPE
    MAPE_x1[item] = (sMAPE(y_val.to("cpu")[:,:,0].squeeze().numpy(), y_hat[:,:,0,1].squeeze().detach().to("cpu").numpy()))
    MAPE_x2[item] = (sMAPE(y_val.to("cpu")[:,:,1].squeeze().numpy(), y_hat[:,:,1,1].squeeze().detach().to("cpu").numpy()))

    # RMSE
    SSE_x1 = SSE_x1 + SSE_compute(y_val.to("cpu")[:,:,0].squeeze().numpy(), y_hat[:,:,0,1].squeeze().detach().to("cpu").numpy())
    SSE_x2 = SSE_x2 + SSE_compute(y_val.to("cpu")[:,:,1].squeeze().numpy(), y_hat[:,:,1,1].squeeze().detach().to("cpu").numpy())


n_item = val_past.shape[0] * val_past.shape[1]
RRMSE_x1 = np.sqrt(np.sum(SSE_x1)/n_item/np.var(y_s_val[:,0]))*100
RRMSE_x2 = np.sqrt(np.sum(SSE_x1)/n_item/np.var(y_s_val[:,1]))*100

MAPE_x1 = np.mean(MAPE_x1)
MAPE_x2 = np.mean(MAPE_x2)

print(f"MAPE_x1 = {MAPE_x1:.2f}%, MAPE_x2 = {MAPE_x2:.2f}%")   
print(f"RRMSE_x1 = {RRMSE_x1:.2f}, RRMSE_x2 = {RRMSE_x2:.2f}")  

# ccc
# Out:
# 100%|██████████| 60942/60942 [01:44<00:00, 583.01it/s]
# MAPE_x1 = 1.24%, MAPE_x2 = 4.25%
# RRMSE_x1 = 5.15, RRMSE_x2 = 4.49
